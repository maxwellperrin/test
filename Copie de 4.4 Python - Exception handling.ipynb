# %% [markdown]
# You must correct each of the scripts below **using exception handling** and **without modifying lists**.

# %% [markdown]
# Script number 1

# %%
list_integers = [1, 12, -45, 6, 27, 0, 24]
for i in list_integers:
  try:
    print(1/i)
  except ZeroDivisionError:
    print("Warning, you try to divide by 0")
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# Warning, you try to divide by 0
# 0.041666666666666664

# %% [markdown]
# Script number 2

# %%
list_integers = [1, 12, -45, 6, 27, 24]
for i in range(10):
  try:
      print(1/list_integers[i])
  except IndexError:
      print("the function range is not well defined")
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# 0.041666666666666664
# the function range is not well defined
# the function range is not well defined
# the function range is not well defined
# the function range is not well defined

# %% [markdown]
# Script number 3

# %%
list_integers = [1, 12, -45, 6, 27, 0, 24]
for i in range(10):
  try:
    print(1/list_integers[i])
  except IndexError:
    print("the function range is not well defined")
  except ZeroDivisionError:
    print("Warning, you try to divide by 0")
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# Warning, you try to divide by 0
# 0.041666666666666664
# the function range is not well defined
# the function range is not well defined
# the function range is not well defined

# %% [markdown]
# Script number 4

# %%
list_words = ['hello', 'good morning', 'GOOD Evening', 34, 'Bye' ]

for word in list_words:
  try:
      print(word.upper())
  except AttributeError:
      print('Invalid Input')
# Out:
# HELLO
# GOOD MORNING
# GOOD EVENING
# Invalid Input
# BYE

# %%
nbreLigne = int(input('Nombre de ligne : '))
#print("#" * nbreLigne)
for loop in range(nbreLigne):
  if loop == 0 or loop == nbreLigne - 1:
     print("#" * nbreLigne)
  else:
    for loop_1 in range(nbreLigne):
      if loop_1 == 0 or loop_1 == nbreLigne - 1:
        print('#', end="")
      else:
        print(".", end='')
    print()
# Out:
# Nombre de ligne : 10
# ##########
# #........#
# #........#
# #........#
# #........#
# #........#
# #........#
# #........#
# #........#
# ##########

# %%
Print how many numbers between 1 and 1000 (inclusive) have an F in their English name.
[ ]

# one two three four five six seven eight nine ten# eleven twelve thirteen fourteen fifteen sixteen seventeen eighteen nineteen
# twenty thirty fourty fifty sixty seventy eighty ninety# hundred and thousand
# 345 is three hundred and forty-five

# %%
# Mission 6: First, choose two arithmetical operations (such as +, -, *, or /)
# Then, create a function that takes in 3 numbers as parameters and carries out those operations, displays a message indicating if the result is positive, negative or zero, and finally returns the result.
# If a division by zero is attempted, display an error message.

# Example with multiplication and addition:
# Calling with 0, 32, 2 will compute (0*32)+2, will display "Positive result", and return 2

# Example with division and addition:
# Calling with 21, 0, 3 will try to compute (21/0)+2, will display "Divide-by-zero error"

# %%
# Mission 4: Create a function that takes a string as input, and return its vowels only, preserving case.
# Example: "Antidisestablishmentarianism" -> "Aiieaieaiai"
# Example: "TO BE OR NOT TO BE" -> "OEOOOE"
def vowel():
  var_mot = input("ecris un mot")
  liste_vowel = ["a","e","i", "o", "u", "y","A","E", "I", "O", "U"]
  for char in var_mot:
    if char in liste_vowel:
      print(char, end="")

vowel()
# Out:
# ecris un motvar_mot = input("ecris un mot") liste_vowel = ["a","e","i", "o", "u", "y","A","E", "I", "O", "U"] for char in var_mot:   if char in liste_vowel:     print(char, end="")
# aoiueiuoieoeaeiouyAEIOUoaiaoiaiieoeiae

# %%
# Mission 6: First, choose two arithmetical operations (such as +, -, *, or /)
# Then, create a function that takes in 3 numbers as parameters and carries out those operations, displays a message indicating if the result is positive, negative or zero, and finally returns the result.
# If a division by zero is attempted, display an error message.

a = int(input())
b = int(input())
c = int(input())


def parametre():
  #print(result)
  result = a + b * c
  if result > 0:
    print(f"ton {result} est positif")
  elif result <= 0:
    print(f"ton {result} est negatif ou nul")

parametre()
# Out:
# 10
# -5
# 3
# ton -5 est negatif ou nul
