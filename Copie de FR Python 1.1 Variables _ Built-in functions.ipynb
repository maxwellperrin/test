# %% [markdown]
# # Type

# %% [markdown]
# 1. Dans la cellule de code ci-dessous, quel est, pour chaque cellule, le type de l'objet x ?
# `indice`: vous pouvez utiliser `type(x)` pour le révéler.

# %% [markdown]
# 1.1

# %%
x = 5

# %%
type(x)
# Out:
# int

# %% [markdown]
# 1.2

# %%
x = "Hello World"

# %%
type(x)
# Out:
# str

# %% [markdown]
# 1.3

# %%
x = 2.5

# %%
type(x)
# Out:
# float

# %% [markdown]
# 1.4

# %%
x = ["mintcream", "burlywood", "salmon"]

# %%
type(x)
# Out:
# list

# %% [markdown]
# 1.5

# %%
x = ("mintcream", "burlywood", "salmon")

# %%
type(x)
# Out:
# tuple

# %% [markdown]
# 1.6

# %%
x = {"name": "Jules César", "Job": "Musician", "age": 55}

# %%
type(x)
# Out:
# dict

# %% [markdown]
# 1.7

# %%
x = True

# %%
type(x)
# Out:
# bool

# %% [markdown]
# 2. Maintenant, vous allez devoir convertir des objets d'un certain type, en un autre type d'objet.
# C'est parti !

# %% [markdown]
# 2.1 Convertissez x en float.

# %%
x = 5

# %%
print(float(x))
# Out:
# 5.0

# %% [markdown]
# 2.2 Convertissez x en int

# %%
x = 5.4

# %%
print(int(x))
# Out:
# 5

# %% [markdown]
# 2.3 Convertissez x en int

# %%
x = 5.6

# %%
print(int(x))
# Out:
# 5

# %% [markdown]
# 2.4 Que pouvez-vous remarquer ?

# %% [markdown]
# Réponse:

# %% [markdown]
# En utilisant la fonction float(), nous pouvons convertir les entiers en décimaux et eb utilisant  En utilisant la fonction int() nous pouvons convertir des décimaux en entiers.

# %% [markdown]
# 2.5 Trouvez le moyen d'arrondir x.

# %%
x = 5.6

# %%
print(round(x))
type(x)
# Out:
# 6
# float

# %% [markdown]
# 2.6 Après avoir arrondi x, est-ce que x est toujours un `float` ?
# Réponse:

# %% [markdown]
# Oui x reste toujours un float

# %%
Oui x reste toujours un float

# %% [markdown]
# 2.7 Ci-dessous, est-ce que x est un `int` ?

# %%
x = 6.0
type(x)
# Out:
# float

# %% [markdown]
# Non x n'est pas un int mais un float

# %% [markdown]
# 2.8 Arrondissez x avec 3 valeurs décimales.

# %%
x = 3.14159265359

# %%
print(round(x,3))
# Out:
# 3.142

# %% [markdown]
# # Built-in Function

# %% [markdown]
# 3.1 Utilisez une [built-in function](https://docs.python.org/3/library/functions.html) pour compter le nombre de lettres dans l'objet de type `string` suivant:

# %%
x = "Hello World"

# %%
x = "Hello World"
Nb_lettres=len(x)-x.count(" ")
print(Nb_lettres)
# Out:
# 10

# %%
print(len("Hello World"))
# Out:
# 11

# %% [markdown]
# 3.2 Utilisez une built-in function pour  compter le nombre d'éléments
#
# ---
#
# dans l'objet de type `list` suivant:
#
# > Bloc en retrait

# %%
x = ["non", "pas", 1, "ni", 2, "ni", 3, "mais", 7.2132]

# %%
print(len(x))
# Out:
# 9

# %% [markdown]
# 3.3 Utilisez une built-in function sur une des deux variables pour que `resultat`  contienne une valeur positive.

# %%
var_1 = 4
var_2 = -5

resultat = var_1 + var_2

# %%
var_1 = 4
var_2 = -5

resultat = var_1 + abs(var_2)

print(resultat)!èè
# Out:
# 9

# %% [markdown]
# 3.4 Utilisez une built-in function pour renvoyer la valeur minimum de la `list` suivante:

# %%
a_list = [3.2, 41, 2, 23, 7]

# %%
#find the smallest number
a_list = [3.2, 41, 2, 23, 7]
minimum_value = min(a_list)
print(minimum_value)
# Out:
# 2

# %% [markdown]
# 3.5 Utilisez une built-in function pour renvoyer la somme des valeurs de la `list` suivante:

# %%
a_list = [3.2, 41, 2, 23, 7]

# %%
#find the sum of numbers

a_list = [3.2, 41, 2, 23, 7]
total = sum(a_list)
print(total)
# Out:
# 76.2
