# %% [markdown]
# # Mission 1
#
# Create a tuple of your choice containing 10 elements in this order:
# - 3 integers
# - 3 strings
# - 2 lists containing 3 items each
# - 2 dictionaries containing 3 items (3 key/value pairs) each

# %%
tuple_1 = (1, 2, 3, "a","b","c",
           ["chat", "chien", "poule"], ["bleu", "blanc", "rouge"],
           {"animaux domestique" : 3, "animaux sauvage": 5, "plante": 10}, {"couleur" : 3, "album de music" : 10, "tableau" : 12 })

# %% [markdown]
# Now, access the second-to-last item in the second list.

# %%
tuple_1[7][1]

#val1,val2,val3 = tuple_1[7]

#(print) = val2
# Out:
# 'blanc'

# %% [markdown]
# # Mission 2
#
# In the same tuple, access the last 4 elements using slicing.

# %%
print(tuple_1[6:11])
# Out:
# (['chat', 'chien', 'poule'], ['bleu', 'blanc', 'rouge'], {'animaux domestique': 3, 'animaux sauvage': 5, 'plante': 10}, {'couleur': 3, 'album de music': 10, 'tableau': 12})

# %% [markdown]
# # Mission 3
#
# Change the value of the 4th element (the first string) of your tuple (since tuples are immutable, this means recreating a tuple where this element is changed).

# %%
new_tuples = list(tuple_1)
#print(new_tuples)
new_tuples[3] = "doggy"
#print(new_tuples)
new_new_tuples = tuple(new_tuples)
print(new_new_tuples)
# Out:
# (1, 2, 3, 'doggy', 'b', 'c', ['chat', 'chien', 'poule'], ['bleu', 'blanc', 'rouge'], {'animaux domestique': 3, 'animaux sauvage': 5, 'plante': 10}, {'couleur': 3, 'album de music': 10, 'tableau': 12})

# %% [markdown]
# # Mission 4
#
# Create 2 tuples of the same length that contain only integers.
#
# Then create a script that compares the sum of their elements and displays the tuple that has the highet total.

# %%
tuple1 = (1,2,3)
tuple2 = (4,5,6)

sum_tuple1 = sum(tuple1)
sum_tuple2 = sum(tuple2)

if sum_tuple1 > sum_tuple2:
  print("tuple1 a un score plus élevé que tuple2:", tuple1)

elif sum_tuple2 > sum_tuple1:
  print("tuple2 a un score plus élevé que tuple2:", tuple2)

else:
  print("les deux ont les mêmes valeurs")
# Out:
# tuple2 a un score plus élevé que tuple2: (4, 5, 6)

# %% [markdown]
# # Mission 5
#
# Here's a tuple:
#
# `my_tuple = ("data analyst", "data scientist", "data engineer", "data architect")`
#
# Ask the user for a string, then for an integer position. Create an altered copy of `my_tuple` where the element at the given position is now the given string.

# %%
my_tuple = ("data analyst", "data scientist", "data engineer", "data architect")

list_2 = list(my_tuple)

list_3 = len(list_2)

string = input("Écrit un mot: ")
position = int(input("écrit un chiffre"))



for index in range(0, list_3):
  list_2[position] = string

#print(list_2)

new_new_tuples = tuple(list_2)
print(new_new_tuples)
# Out:
# Écrit un mot: doggy
# écrit un chiffre2
# ('data analyst', 'data scientist', 'doggy', 'data architect')
