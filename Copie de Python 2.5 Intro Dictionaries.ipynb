# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
people = {"Gontran": 23,
          "Jason": 42,
          "Ayoub": 27}


for i in people:
  print(i)
# Out:
# Gontran
# Jason
# Ayoub

# %%
type(i)
# Out:
# str

# %% [markdown]
# 1. What does `i` correspond to?
# To answer, you must use the terms "keys" and "values".

# %%
# I correspond à chaques clés du dictionnaire

# %% [markdown]
# Answer:

# %%
for i in people.keys():
  print(i)
# Out:
# Gontran
# Jason
# Ayoub

# %%
for i in people.values():
  print(i)
# Out:
# 23
# 42
# 27

# %% [markdown]
# 2. What does `i` correspond to in the second last cell?
# What does `i` in the last cell correspond to?
# Why do you ask?

# %%
# I correspond à chaques clés du dictionnaire
# I correspond à chaques valeurs du dictionnaire
# On cherche à trouver les clés et les valeurs qui sont dans le dictionnaire

# %% [markdown]
# Answer:

# %%
for i in people.items():
  print(i)
# Out:
# ('Gontran', 23)
# ('Jason', 42)
# ('Ayoub', 27)

# %% [markdown]
# 3. What is the type of object returned here called?

# %%
type(i)
# Out:
# tuple

# %% [markdown]
# Answer:

# %%
for i, age in people.items():
  print(i, age)
# Out:
# Gontran 23
# Jason 42
# Ayoub 27

# %% [markdown]
# 4. Here I can recover the age of the people. How could I retrieve their names?

# %%
# avec print(i)

# %% [markdown]
# Answer:

# %% [markdown]
# # Mission 2

# %%
people = {"Gontran": 23,
          "Jason": 42,
          "Ayoub": "27",
          "Léo": [10,20,30],
          "Rosario": {"Juan": 3,
                      "Camelia": 6}}


for i in people.values():
  print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# 1. Does the above code allow me to confirm that I can have values of different types within a dictionary?

# %%
# Oui on peut avoir différentes valeurs dans un dictionnaire

# %% [markdown]
# Answer:

# %% [markdown]
# 2. Can I have keys of different types within a dictionary?

# %%
# Oui, il est possible différents types de clés dans un dictionnaire

# %% [markdown]
# Answer:

# %%
people["Ayoub"] = int(people["Ayoub"])
people["maxwell"] = 27

for i in people.values():
  print((i))

print(people)
# Out:
# 23
# 42
# 27
# [10, 20, 30]
# {'Juan': 3, 'Camelia': 6}
# 27
# {'Gontran': 23, 'Jason': 42, 'Ayoub': 27, 'Léo': [10, 20, 30], 'Rosario': {'Juan': 3, 'Camelia': 6}, 'maxwell': 27}

# %% [markdown]
# 3. What did the above code allow me to do?

# %%
# Le code nous permet de transformer la valeur de la clé "Ayoub" en un entier

# %% [markdown]
# Answer:

# %% [markdown]
# # Mission 3

# %%
groups = {"groupe_1": ["Lam", "Ghizlaine", "Khaled", "Florian"],
          "groupe_2": ["Lucile", "Mbaye", "Cécile", "Rohan"],
          "groupe_3": ["Agathe", "Charlotte", "Charles", "Maxime"],
          "groupe_4": ["Gaelle", "Linh", "Meral"]}


for i in groups.values():
  print(i)
# Out:
# ['Lam', 'Ghizlaine', 'Khaled', 'Florian']
# ['Lucile', 'Mbaye', 'Cécile', 'Rohan']
# ['Agathe', 'Charlotte', 'Charles', 'Maxime']
# ['Gaelle', 'Linh', 'Meral']

# %% [markdown]
# 1. What is the type of each value?
# How do I get into each list?

# %%
type(i)
# Out:
# list

# %%
# Nous avons à faire à des listes
# En demandant d'afficher les valeurs du dictionnaire

# %% [markdown]
# Answer:

# %%
for i in groups.values():
  for v in i:
    print(v)
# Out:
# Lam
# Ghizlaine
# Khaled
# Florian
# Lucile
# Mbaye
# Cécile
# Rohan
# Agathe
# Charlotte
# Charles
# Maxime
# Gaelle
# Linh
# Meral

# %% [markdown]
# 2. How did I get into each list?
# Take the time to explain your reasoning for answering this question.

# %% [markdown]
# Answer:

# %%
#Dans la première boucle, on a demandé de chercher l'index de chaques listes du dictionnaire pour récuperer les listes, puis on a imbriqué une deuxième boucle pour chercher les valeurs des listes gràce à l'index des premières listes. Ce qui permet d'afficher les valeurs de chaques listes du dictionnaire.
