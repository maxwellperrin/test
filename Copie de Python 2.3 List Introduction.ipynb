# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
names = ["Fredy", "Nicolas", "Alexandre"]

for i in enumerate(names):
  print(i)
# Out:
# (0, 'Fredy')
# (1, 'Nicolas')
# (2, 'Alexandre')

# %% [markdown]
# 1. What type of object is returned as output?
# Hint: You can use `type(i)`.

# %% [markdown]
# Answer:

# %%
for i, val in enumerate(names):
  print(i)
# Out:
# 0
# 1
# 2

# %%
# on a demandé d'afficher l'index de chaques valeurs de la variable qui se situent dans la boucle for

# %%
for i, val in enumerate(names):
  print(val)
# Out:
# Fredy
# Nicolas
# Alexandre

# %% [markdown]
# 2. What does `i` correspond to?
# What does `val` correspond to?
# Why is it so?

# %% [markdown]
# Answer:

# %%
# I correspond à integer donc l'index de chaque valeur
# val correspond aux valeurs qui se trouvent dans la liste name
# On a parcouru la liste noms et d'afficher les valeurs de chaque élément de la liste

# %%
for val, i in enumerate(names):
  print(i)
# Out:
# Fredy
# Nicolas
# Alexandre

# %%
#On a parcouru l'index et généré les valeurs pour chaque élément de la liste

# %%
for val, i in enumerate(names):
  print(val)
# Out:
# 0
# 1
# 2

# %%
#On a parcouru l'index et généré l'index pour chaque élément de la liste

# %% [markdown]
# 3. This time, `i` returns first names and `val` returns numbers. Why is it so?

# %% [markdown]
# Answer:

# %% [markdown]
# 4. What does the built in function `enumerate` do?
# In what cases can it be useful?

# %% [markdown]
# Answer:

# %%
# la fonction enumerate permet d'afficher l'index et d'afficher les strings de la list.
# La fonction enumarate permet de parcourir une collection d’éléments tout en gardant une trace de l’index de l’élément actuel dans une variable de compteur.

# %% [markdown]
# # Mission 2

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list[8] = "Marshall"

test_list
# Out:
# ['Hi', 'my', 'name', 'is', 'hi', 'my', 'name', 'is', 'Marshall']

# %% [markdown]
# 1. What does the 8 in square brackets mean?
# What action has been performed?

# %%
# Le 8 dans les crochets représentent l'index de chaque élément de la liste.
# Elle a demandé de replancer la valeur situé à l'index 8 par une autre valeur.

# %% [markdown]
# Answer:

# %%
for i in range(4):
  print(test_list[i])
# Out:
# Hi
# my
# name
# is

# %% [markdown]
# 2. What does `range(4)` mean?
# Why are only the first 4 elements of `test_list` displayed?

# %%
# Pour la variable test_list, la fonction range permet de créer une séquence allant de 0 à 3 dans la list.
# La première valeur de la liste correspond à l'index 0 de la séquence. C'est pour cela qu'il n'y a que 4 elements affichés.

# %% [markdown]
# Answer:

# %%
for i in range(2,8,2):
  print(test_list[i])
# Out:
# name
# hi
# name

# %% [markdown]
# 3. What does `range(2,8,2)` mean ?
# Why are only the elements 'name', 'hi' and 'name' displayed?

# %% [markdown]
# Answer:

# %%
# Pour la variable test_list, on demande à la fonction range de commencer à l'index 0 et de finir à l'index 8 de la list tout en avancant d'un pas de 2. Il n'y a que les éléments "name", "hi", "name" car on demande à la fonction range de terminer par l'index 8. Si on avait envie d'affiché l'index 8, on aurait demandé à range de terminer par l'index 9 pour afficher l'index 8.

# %% [markdown]
# # Mission 3

# %%
numbers = [2,3,1,5,9]

for i in range(10,15):
  numbers.append(i)

numbers
# Out:
# [2, 3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 1. What does `range(10,15)` mean ?
#   What is the purpose of the method `append()` ?

# %%
# range(10,15) correspond à la séquence de nombre allant de 10 à 15.
# La méthode append() permet d'ajouter cette séquence de nombre dans la variable numbers dont la liste comprend les nombres [2, 3, 1, 5, 9]

# %% [markdown]
# Answer:

# %%
del numbers[0]

numbers
# Out:
# [3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 2. What is the purpose of the `del` command?

# %%
# la commande del permet de supprimer un "int","string".... En l'occurance dans cette exemple, on a demandé de supprimer le numéro situé à l'index 0

# %% [markdown]
# Answer:

# %% [markdown]
# # Mission 4

# %%
import random

random.randint(0,10)
# Out:
# 5

# %% [markdown]
# 1. What can the method `randint()` do ?

# %%
# la commande random.randint permet d'afficher un nombre situé dans la séquence de nombre définit entre (0,10).

# %% [markdown]
# Answer:

# %%
numbers.insert(5, "hey hey hey")
numbers
# Out:
# [3, 1, 5, 9, 10, 'hey hey hey', 11, 12, 13, 14]

# %% [markdown]
# 2. What can the method `.insert()` do ?
# You must answer using the terms 'parameter' and 'argument'.

# %%
# La method .insert() permet d'ajouter dans la list numbers l'argument "hey hey hey" après le paramètre 5 de la liste number.

# %% [markdown]
# Answer:

# %% [markdown]
# # Mission 5

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list = " ".join(test_list)

test_list
# Out:
# 'Hi my name is hi my name is chickychicky'

# %% [markdown]
# 1. What can the `.join()` method do?
# What is the type of `test_list` before using `.join()`?
# What is the type of `test_list` after using `.join()`?

# %%
# La method .join() permet de transformer tous les items de la liste et une seule string.
# Avant d'uitliser la methode .join() test_list était une list.
# Après l'utilisation de la methode .join() test_list est devenue un string.

# %% [markdown]
# Answer:

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"

christmas.split()
# Out:
# ['Noël',
#  "c'est",
#  'bien,',
#  'mais',
#  'attention',
#  'à',
#  'ne',
#  'pas',
#  'manger',
#  'trop',
#  'de',
#  'chocolat.',
#  'On',
#  'le',
#  'sait,',
#  'mais',
#  'on',
#  'le',
#  'fais',
#  'à',
#  'chaque',
#  'fois.',
#  "C'est",
#  'la',
#  'vie']

# %% [markdown]
# 2. What can the `.split()` method do?
# What is the type of `christmas` before using `.split()`?
# What is the type of `christmas` after using `.split()`?

# %%
# La method .split() permet de transformer une chaîne de caractère en une liste. Chaque caractère devient un item.
# Avant d'utiliser la method . split la variable christmas était un argument, une chaine de charactère --> string.
# Après la method .split la variable christmas est devenue une list

type(christmas.split())
# Out:
# list

# %% [markdown]
# Answer:

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"


christmas.split("à")
# Out:
# ["Noël c'est bien, mais attention ",
#  ' ne pas manger trop de chocolat. On le sait, mais on le fais ',
#  " chaque fois. C'est la vie"]

# %% [markdown]
# 3. Why does the `.split()` method split the `string` into 3 elements?

# %%
# Elle sépare la variable en 3 éléments car on a demandé de diviser la chaîne de caractère en 3 items à partir du caractère 3.

# %% [markdown]
# Answer:
